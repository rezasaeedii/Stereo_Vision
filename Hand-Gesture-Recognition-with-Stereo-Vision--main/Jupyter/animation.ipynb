# %%
import matplotlib.pyplot as plt
from matplotlib.animation import FuncAnimation
import math

# %%
x1 = [1, 2 , 3, 4, 5, 6]
y1 = [x*2 for x in x1]
y2 = [math.sin(x) for x in x1]

# %%
plt.figure(1)
plt.plot(x1, y1)
# plt.figure(2)
plt.plot(x1, y2)
plt.show()
